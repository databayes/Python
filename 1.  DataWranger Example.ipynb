# %%
df = spark.read.format("csv").option("header","true").load("abfss://1fe39462-9846-4fe4-93dd-46978e9def3a@onelake.dfs.fabric.microsoft.com/a1121598-372c-4ac8-bc11-78500c7274bc/Files/HR_file.csv")
# df now is a Spark DataFrame containing CSV data from "abfss://1fe39462-9846-4fe4-93dd-46978e9def3a@onelake.dfs.fabric.microsoft.com/a1121598-372c-4ac8-bc11-78500c7274bc/Files/HR_file.csv".
display(df)
# Out:
# StatementMeta(, c83baa74-d1df-41db-9ac3-00a6893b2dbf, 3, Finished, Available)
# SynapseWidget(Synapse.DataFrame, 45ec57c5-a001-4379-b92f-70cd18afc3f9)

# %%
# Code generated by Data Wrangler for PySpark DataFrame

from pyspark.sql import functions as F

def clean_data(df):
    # Drop duplicate rows across all columns
    df = df.dropDuplicates()
    # Replace missing values with "0" in columns: 'satisfaction_level', 'last_evaluation', 'time_spend_company'
    df = df.fillna(value="0", subset=['satisfaction_level', 'last_evaluation', 'time_spend_company'])
    # Capitalize the first character in columns: 'Departments', 'salary'
    df = df.withColumn('Departments', F.initcap(F.col('Departments')))
    df = df.withColumn('salary', F.initcap(F.col('salary')))
    return df

df_clean = clean_data(df)
display(df_clean)
# Out:
# StatementMeta(, c83baa74-d1df-41db-9ac3-00a6893b2dbf, 57, Finished, Available)
# SynapseWidget(Synapse.DataFrame, 3beedce5-c749-49b4-9b4b-858b612f8ab4)
