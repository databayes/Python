# %%
df = spark.read.format("csv").option("header","true").load("abfss://1fe39462-9846-4fe4-93dd-46978e9def3a@onelake.dfs.fabric.microsoft.com/a1121598-372c-4ac8-bc11-78500c7274bc/Files/HR_file.csv")
# df now is a Spark DataFrame containing CSV data from "abfss://1fe39462-9846-4fe4-93dd-46978e9def3a@onelake.dfs.fabric.microsoft.com/a1121598-372c-4ac8-bc11-78500c7274bc/Files/HR_file.csv".
display(df)
# Out:
# StatementMeta(, 9780cd96-7031-451f-abc5-a9d7f616db80, 3, Finished, Available)
# SynapseWidget(Synapse.DataFrame, 1c48057f-dfc2-40a8-b4dc-3cc101dfff07)

# %%
# Code generated by Data Wrangler for PySpark DataFrame

def clean_data(df):
    # Filter rows based on column: 'Departments'
    df = df.filter(df['Departments'] == "technical")
    # Drop rows with missing data in columns: 'satisfaction_level', 'last_evaluation', 'time_spend_company'
    df = df.dropna(subset=['satisfaction_level', 'last_evaluation', 'time_spend_company'])
    return df

df_clean = clean_data(df)
display(df_clean)
# Out:
# StatementMeta(, 9780cd96-7031-451f-abc5-a9d7f616db80, 31, Finished, Available)
# SynapseWidget(Synapse.DataFrame, f813150f-31eb-49d6-8803-79db7993fbec)
