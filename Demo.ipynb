# %%
# Welcome to your new notebook
# Type here in the cell editor to add code!
# Out:
# StatementMeta(, bd6d472a-f6e9-4af4-9693-f3cde01de851, 3, Finished, Available)

# %%
import pandas as pd
# Load data into pandas DataFrame from "/lakehouse/default/" + "Files/HR_file_with_nulls.csv"
df = pd.read_csv("/lakehouse/default/" + "Files/HR_file.csv")
display(df)
# Out:
# StatementMeta(, bd6d472a-f6e9-4af4-9693-f3cde01de851, 4, Finished, Available)
# SynapseWidget(Synapse.DataFrame, 838ce0b3-50ca-4f1b-b84d-c51c231d1874)

# %% [markdown]
# #### **Purpose**: This session aims to unlock Python’s potential for data analytics, making it accessible
# ###### **Created by**: Sue
# ###### Introduction to Python and data analysis
# 1. Python basics: syntax, variables, data types, control structures, functions and libraries
# 2. The Pandas library: dataframes and series, data import/export, filter, sort
# 3. Data cleaning & visualisation e.g., handling missing data
# 4. Visualisation with the matplotlib/seaborn packages

# %%
#To write a comment
#Enter allows you to enter data within the cell, Shift+Enter
print("Hello World")
# Out:
# StatementMeta(, bd6d472a-f6e9-4af4-9693-f3cde01de851, 5, Finished, Available)
# Hello World

# %%
print("\\n allows you to add in a new line. \nUsing the \\ allows you to use a special character")
# Out:
# StatementMeta(, bd6d472a-f6e9-4af4-9693-f3cde01de851, 6, Finished, Available)
# \n allows you to add in a new line.
# Using the \ allows you to use a special character

# %% [markdown]
# Choosing the cell to be Markdown allows you to write text and format it to make your scripts readable.
# Highly recommend the Seattle data guy's posts:<br>
# https://www.theseattledataguy.com/intro-data-analysis-everyone-part-1/#page-content

# %%
if 5 > 2:
    print("This is correct, duh")
# Out:
# StatementMeta(, bd6d472a-f6e9-4af4-9693-f3cde01de851, 7, Finished, Available)
# This is correct, duh

# %%
# Use of an if leads us to the if logic

if 5 > 2:
    print("Yes")
else:
    print("No")
# Out:
# StatementMeta(, bd6d472a-f6e9-4af4-9693-f3cde01de851, 8, Finished, Available)
# Yes

# %% [markdown]
# ###### **Variables**
# A variable is created the moment you assign a value to it
# ###### Variable Rules:
# - must start with a letter or _
# - cannot start with a number
# - can only contain alpha-numeric characters and _
# - are CASE-sensitive
# - cannot be a keyword

# %%
# This will always lead us to Y so perhaps we might want to specify a variable

a = 5
b = 20

if a > b:
    print("yes, duh")
else:
    print("no")
# Out:
# StatementMeta(, bd6d472a-f6e9-4af4-9693-f3cde01de851, 9, Finished, Available)
# no

# %%
# Define two variables and add in a multiple if statements
number = 12
threshold = 12

# If-then-else statement to compare number and threshold
if number > threshold:
    print("The number is greater than the threshold.")
elif number == threshold:
    print("The number is equal to the threshold.")
else:
    print("The number is less than the threshold.")
# Out:
# StatementMeta(, bd6d472a-f6e9-4af4-9693-f3cde01de851, 10, Finished, Available)
# The number is equal to the threshold.

# %%
def compare_values(number, threshold):
    """
    Compares the number against the threshold and prints a message based on the comparison.

    Parameters:
    - number: The number to compare.
    - threshold: The threshold against which the number is compared.
    """
    if number > threshold:
        print("The number is greater than the threshold.")
    elif number == threshold:
        print("The number is equal to the threshold.")
    else:
        print("The number is less than the threshold.")

compare_values(10,5)
# Out:
# StatementMeta(, bd6d472a-f6e9-4af4-9693-f3cde01de851, 11, Finished, Available)
# The number is greater than the threshold.

# %%
compare_values(20,20)
# Out:
# StatementMeta(, bd6d472a-f6e9-4af4-9693-f3cde01de851, 12, Finished, Available)
# The number is equal to the threshold.

# %%
# Define a list of numbers
numbers = [1, 2, 3, 4, 5]

# Use a for loop to iterate over the list
for number in numbers:
    doubled = number * 2
    #print(str(number) + " doubled is " + str(doubled))
    print(f"{number} doubled is {doubled}")
# Out:
# StatementMeta(, bd6d472a-f6e9-4af4-9693-f3cde01de851, 13, Finished, Available)
# 1 doubled is 2
# 2 doubled is 4
# 3 doubled is 6
# 4 doubled is 8
# 5 doubled is 10

# %%
# Initialize a counter variable
counter = 5

# Loop as long as counter is greater than 0
while counter > 0:
    print("Countdown:", counter)
    # Decrement the counter
    counter -= 1

print("Lift off!")
# Out:
# StatementMeta(, bd6d472a-f6e9-4af4-9693-f3cde01de851, 14, Finished, Available)
# Countdown: 5
# Countdown: 4
# Countdown: 3
# Countdown: 2
# Countdown: 1
# Lift off!

# %%
# Initialize the variable
number = 0

# Loop indefinitely
while True:
    number += 1
    print(number)
    # Exit loop when number reaches 5
    if number >= 5:
        print("Stopping at 5")
        break
# Out:
# StatementMeta(, bd6d472a-f6e9-4af4-9693-f3cde01de851, 15, Finished, Available)
# 1
# 2
# 3
# 4
# 5
# Stopping at 5

# %%
# Check if counter is an integer and non-negative

counter = 10

if not isinstance(counter, int) or counter < 0:
    # More specific error message
    raise ValueError("Counter must be an integer and non-negative.")

# Loop as long as counter is greater than 0
while counter > 0:
    print("Countdown:", counter)
    # Decrement the counter
    counter -= 1

print("Lift off!")
# Out:
# StatementMeta(, bd6d472a-f6e9-4af4-9693-f3cde01de851, 16, Finished, Available)
# Countdown: 10
# Countdown: 9
# Countdown: 8
# Countdown: 7
# Countdown: 6
# Countdown: 5
# Countdown: 4
# Countdown: 3
# Countdown: 2
# Countdown: 1
# Lift off!

# %%
from IPython.display import display, HTML

# Initialize the variable
number = 0

# Loop indefinitely
while True:
    number += 1
    print(number)
    # Exit loop when number reaches 5
    if number >= 5:
        display(HTML('<b style="font-size: 20px;">Stopping at 5</b>'))
        break
# Out:
# StatementMeta(, bd6d472a-f6e9-4af4-9693-f3cde01de851, 17, Finished, Available)
# 1
# 2
# 3
# 4
# 5
# <b style="font-size: 20px;">Stopping at 5</b>

# %% [markdown]
# ###### **NumPy**
#
# A powerful library for numerical computing in Python:
# - Efficient Array Handling
# - Broad Range of Mathematical Functions
# - Multi-dimensional Array Support
# - Slicing and Indexing
# - Integration with Other Libraries
#     - NumPy arrays form the backbone of Pandas DataFrames and Series
#     - Matplotlib primarily handles visualisation in Python and relies on NumPy
#     - Scikit-learn - library for Machine Learning - NumPy and SciPy

# %%
import pandas as pd
import numpy as np

# Create a DataFrame from a dictionary
data = {
    'Temperature (C)': [20, 22, 24, 26, 28],
    'Humidity (%)': [30, 35, 40, 45, 50]
}

#This creates a DataFrame with two columns, each column is essentially a NumPy array under the hood
dfWeather = pd.DataFrame(data)
print(dfWeather)
# Out:
# StatementMeta(, bd6d472a-f6e9-4af4-9693-f3cde01de851, 18, Finished, Available)
#    Temperature (C)  Humidity (%)
# 0               20            30
# 1               22            35
# 2               24            40
# 3               26            45
# 4               28            50

# %%
# Add a new column for temperature in Fahrenheit
# note the syntax to select a column
dfWeather['Temperature (F)'] = dfWeather['Temperature (C)'] * 9/5 + 32
print(dfWeather)
# Out:
# StatementMeta(, bd6d472a-f6e9-4af4-9693-f3cde01de851, 19, Finished, Available)
#    Temperature (C)  Humidity (%)  Temperature (F)
# 0               20            30             68.0
# 1               22            35             71.6
# 2               24            40             75.2
# 3               26            45             78.8
# 4               28            50             82.4

# %%
# Filter rows where Humidity is greater than 40%
# Note the syntax - first set of brackets sepcifies the context, eg, filtering, 
# second set applies the boolean mask to the dataframe and selects only those rows

high_humidity = dfWeather[dfWeather['Humidity (%)'] > 40]
print(high_humidity)
# Out:
# StatementMeta(, bd6d472a-f6e9-4af4-9693-f3cde01de851, 20, Finished, Available)
#    Temperature (C)  Humidity (%)  Temperature (F)
# 3               26            45             78.8
# 4               28            50             82.4

# %%
display(df)
# Out:
# StatementMeta(, bd6d472a-f6e9-4af4-9693-f3cde01de851, 21, Finished, Available)
#        satisfaction_level  last_evaluation  number_project  \
# 0                   0.304             0.53               2
# 1                   0.640             0.86               5
# 2                   0.088              NaN               7
# 3                   0.576             0.87               5
# 4                   0.296             0.52               2
# ...                   ...              ...             ...
# 14994               0.400             0.57               2
# 14995               0.370             0.48               2
# 14996               0.370             0.53               2
# 14997                 NaN             0.96               6
# 14998               0.370             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                 2.0              0     1
# 1                       262                 5.0              0     1
# 2                       272                 3.0              0     1
# 3                       223                 4.0              0     1
# 4                       159                 2.0              0     1
# ...                     ...                 ...            ...   ...
# 14994                   151                 3.0              0     1
# 14995                   160                 3.0              0     1
# 14996                   143                 3.0              0     1
# 14997                   280                 4.0              0     1
# 14998                   158                 3.0              0     1
#
#        promotion_last_5years Departments salary
# 0                          0       sales    low
# 1                          0       sales    low
# 2                          0       sales    low
# 3                          0       sales    low
# 4                          0       sales    low
# ...                      ...         ...    ...
# 14994                      0     support    low
# 14995                      0     support    low
# 14996                      0     support    low
# 14997                      0     support    low
# 14998                      0     support    low
#
# [14999 rows x 10 columns]

# %%
print(df.tail(10))
# Out:
# StatementMeta(, bd6d472a-f6e9-4af4-9693-f3cde01de851, 22, Finished, Available)
#        satisfaction_level  last_evaluation  number_project  \
# 14989                 NaN             0.57               2
# 14990                0.89             0.88               5
# 14991                0.09             0.81               6
# 14992                0.40             0.48               2
# 14993                 NaN             0.83               6
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                 NaN             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 14989                   159                 3.0              1     1
# 14990                   228                 5.0              1     1
# 14991                   257                 4.0              0     1
# 14992                   155                 3.0              0     1
# 14993                   293                 6.0              0     1
# 14994                   151                 3.0              0     1
# 14995                   160                 3.0              0     1
# 14996                   143                 3.0              0     1
# 14997                   280                 4.0              0     1
# 14998                   158                 3.0              0     1
#
#        promotion_last_5years Departments salary
# 14989                      0   technical    low
# 14990                      0     support    low
# 14991                      0     support    low
# 14992                      0     support    low
# 14993                      0     support    low
# 14994                      0     support    low
# 14995                      0     support    low
# 14996                      0     support    low
# 14997                      0     support    low
# 14998                      0     support    low

# %%
random_rows = df.sample(n=5)  # Change 'n' to the desired number of random rows

# Print the randomly selected rows
print(random_rows)
# Out:
# StatementMeta(, bd6d472a-f6e9-4af4-9693-f3cde01de851, 23, Finished, Available)
#       satisfaction_level  last_evaluation  number_project  \
# 7765               0.360             0.61               4
# 5116               0.850             0.79               3
# 5650               0.792             0.82               6
# 4254               0.540             0.60               3
# 7793               0.712             0.73               3
#
#       average_montly_hours  time_spend_company  Work_accident  left  \
# 7765                   166                 4.0              0     0
# 5116                   243                 2.0              0     0
# 5650                   185                 3.0              1     0
# 4254                   209                 2.0              0     0
# 7793                   274                 1.0              0     0
#
#       promotion_last_5years Departments  salary
# 7765                      0   technical     low
# 5116                      1   technical  medium
# 5650                      0       sales     low
# 4254                      0     support     low
# 7793                      0       sales     low

# %%
# Get a concise summary
print(df.info())
# Out:
# StatementMeta(, bd6d472a-f6e9-4af4-9693-f3cde01de851, 24, Finished, Available)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfaction_level     14250 non-null  float64
#  1   last_evaluation        14250 non-null  float64
#  2   number_project         14999 non-null  int64
#  3   average_montly_hours   14999 non-null  int64
#  4   time_spend_company     14464 non-null  float64
#  5   Work_accident          14999 non-null  int64
#  6   left                   14999 non-null  int64
#  7   promotion_last_5years  14999 non-null  int64
#  8   Departments            14999 non-null  object
#  9   salary                 14999 non-null  object
# dtypes: float64(3), int64(5), object(2)
# memory usage: 1.1+ MB
# None

# %%
# Get a summary of the descriptive statistics of each numeric column
print(df.describe())
# Out:
# StatementMeta(, bd6d472a-f6e9-4af4-9693-f3cde01de851, 25, Finished, Available)
#        satisfaction_level  last_evaluation  number_project  \
# count        14250.000000     14250.000000    14999.000000
# mean             0.579696         0.716338        3.803054
# std              0.241904         0.171144        1.232592
# min              0.072000         0.360000        2.000000
# 25%              0.410000         0.560000        3.000000
# 50%              0.600000         0.720000        4.000000
# 75%              0.768000         0.870000        5.000000
# max              1.000000         1.000000        7.000000
#
#        average_montly_hours  time_spend_company  Work_accident          left  \
# count          14999.000000        14464.000000   14999.000000  14999.000000
# mean             201.050337            3.195174       0.144610      0.238083
# std               49.943099            1.538598       0.351719      0.425924
# min               96.000000            1.000000       0.000000      0.000000
# 25%              156.000000            2.000000       0.000000      0.000000
# 50%              200.000000            3.000000       0.000000      0.000000
# 75%              245.000000            4.000000       0.000000      0.000000
# max              310.000000           10.000000       1.000000      1.000000
#
#        promotion_last_5years
# count           14999.000000
# mean                0.021268
# std                 0.144281
# min                 0.000000
# 25%                 0.000000
# 50%                 0.000000
# 75%                 0.000000
# max                 1.000000

# %%
columns = print(df.columns)
# Out:
# StatementMeta(, bd6d472a-f6e9-4af4-9693-f3cde01de851, 26, Finished, Available)
# Index(['satisfaction_level', 'last_evaluation', 'number_project',
#        'average_montly_hours', 'time_spend_company', 'Work_accident', 'left',
#        'promotion_last_5years', 'Departments', 'salary'],
#       dtype='object')

# %%
column_names = df.columns.tolist()
print(column_names)
# Out:
# StatementMeta(, bd6d472a-f6e9-4af4-9693-f3cde01de851, 27, Finished, Available)
# ['satisfaction_level', 'last_evaluation', 'number_project', 'average_montly_hours', 'time_spend_company', 'Work_accident', 'left', 'promotion_last_5years', 'Departments', 'salary']

# %%
# Assuming 'column_names' is a list of column names
for column in column_names:
    print(f"Column '{column}' has data type: {type(df[column][0])}")
# Out:
# StatementMeta(, bd6d472a-f6e9-4af4-9693-f3cde01de851, 28, Finished, Available)
# Column 'satisfaction_level' has data type: <class 'numpy.float64'>
# Column 'last_evaluation' has data type: <class 'numpy.float64'>
# Column 'number_project' has data type: <class 'numpy.int64'>
# Column 'average_montly_hours' has data type: <class 'numpy.int64'>
# Column 'time_spend_company' has data type: <class 'numpy.float64'>
# Column 'Work_accident' has data type: <class 'numpy.int64'>
# Column 'left' has data type: <class 'numpy.int64'>
# Column 'promotion_last_5years' has data type: <class 'numpy.int64'>
# Column 'Departments' has data type: <class 'str'>
# Column 'salary' has data type: <class 'str'>

# %%
print(df['satisfaction_level'].describe())
#method pulled from dataframe because the column is an object
# Out:
# StatementMeta(, bd6d472a-f6e9-4af4-9693-f3cde01de851, 29, Finished, Available)
# count    14250.000000
# mean         0.579696
# std          0.241904
# min          0.072000
# 25%          0.410000
# 50%          0.600000
# 75%          0.768000
# max          1.000000
# Name: satisfaction_level, dtype: float64

# %%
#Replace 'old_column_name' with 'new_column_name'
new_column_name = 'average_monthly_hours'
df.rename(columns={'average_montly_hours': new_column_name}, inplace=True)
print(df.columns)
# Out:
# StatementMeta(, bd6d472a-f6e9-4af4-9693-f3cde01de851, 30, Finished, Available)
# Index(['satisfaction_level', 'last_evaluation', 'number_project',
#        'average_monthly_hours', 'time_spend_company', 'Work_accident', 'left',
#        'promotion_last_5years', 'Departments', 'salary'],
#       dtype='object')

# %%
# Replace '_' with ' ' in column names
df_copy = df.copy()

# Modify the column names in the copy
df_copy.columns = [col.replace('_', ' ').title() for col in df_copy.columns]

# View the modified column names in the copy
print(df_copy.columns)
# df.columns is an attribute of df which contains an index of the column names.
# The for statement allows us to iterate over each column name and replace the _ with a space
# by applying the [ ] this allows us to create a new list for df.columns

df.columns = [col.replace('_', ' ').title() for col in df.columns]
# Out:
# StatementMeta(, bd6d472a-f6e9-4af4-9693-f3cde01de851, 31, Finished, Available)
# Index(['Satisfaction Level', 'Last Evaluation', 'Number Project',
#        'Average Monthly Hours', 'Time Spend Company', 'Work Accident', 'Left',
#        'Promotion Last 5Years', 'Departments', 'Salary'],
#       dtype='object')

# %%
df.shape
# Out:
# StatementMeta(, bd6d472a-f6e9-4af4-9693-f3cde01de851, 32, Finished, Available)
# (14999, 10)

# %%
# Check for missing values
print(df.isnull().sum())
df.shape
# Out:
# StatementMeta(, bd6d472a-f6e9-4af4-9693-f3cde01de851, 33, Finished, Available)
# Satisfaction Level       749
# Last Evaluation          749
# Number Project             0
# Average Monthly Hours      0
# Time Spend Company       535
# Work Accident              0
# Left                       0
# Promotion Last 5Years      0
# Departments                0
# Salary                     0
# dtype: int64
# (14999, 10)

# %%
nan_count = df['Satisfaction Level'].isna().sum()
print("Number of NaN values in 'Satisfaction Level':", nan_count)

data_type = df['Satisfaction Level'].dtype  # Returns the data type of 'column_name'
print("Data Type is: ", data_type)

# Calculate the minimum and maximum values of the 'satisfaction_level' column
min_satisfaction = df['Satisfaction Level'].min()
max_satisfaction = df['Satisfaction Level'].max()

# Print or display the minimum and maximum values
print("Minimum Satisfaction Level:", min_satisfaction)
print("Maximum Satisfaction Level:", max_satisfaction)
# Out:
# StatementMeta(, bd6d472a-f6e9-4af4-9693-f3cde01de851, 34, Finished, Available)
# Number of NaN values in 'Satisfaction Level': 749
# Data Type is:  float64
# Minimum Satisfaction Level: 0.072
# Maximum Satisfaction Level: 1.0

# %%
# Drop or fill missing values if needed (example)
df_cleaned = df.dropna() # Drop rows with missing values # inplace=True would remove in place
print(df_cleaned.shape)
# Out:
# StatementMeta(, bd6d472a-f6e9-4af4-9693-f3cde01de851, 35, Finished, Available)
# (13075, 10)

# %%
# To print the number of rows and columns more clearly, you could do:
num_rows, num_columns = df.shape
print("Number of rows:", num_rows)
print("Number of columns:", num_columns)

df_filledZeros = df.fillna(0) # Fill missing values with 0  
print(df_filledZeros.shape)
print(df_filledZeros.isnull().sum())
# Out:
# StatementMeta(, bd6d472a-f6e9-4af4-9693-f3cde01de851, 36, Finished, Available)
# Number of rows: 14999
# Number of columns: 10
# (14999, 10)
# Satisfaction Level       0
# Last Evaluation          0
# Number Project           0
# Average Monthly Hours    0
# Time Spend Company       0
# Work Accident            0
# Left                     0
# Promotion Last 5Years    0
# Departments              0
# Salary                   0
# dtype: int64

# %%
# Get the number of rows in each DataFrame
num_rows_df = df.shape[0]
num_rows_df_cleaned = df_cleaned.shape[0]

# Calculate the difference in the number of rows
difference_in_rows = num_rows_df - num_rows_df_cleaned

# Print the result
print(f"Difference in the number of rows: {difference_in_rows}")
# Out:
# StatementMeta(, bd6d472a-f6e9-4af4-9693-f3cde01de851, 37, Finished, Available)
# Difference in the number of rows: 1924

# %%
import matplotlib.pyplot as plt
department_counts = df['Departments'].value_counts()
salary_counts = df['Salary'].value_counts()

plt.figure(figsize=(14, 6))

# Bar chart for Departments
plt.subplot(1, 2, 1)
plt.bar(department_counts.index, department_counts.values, color='skyblue')
plt.title('Distribution of Departments')
plt.xticks(rotation=45)
plt.ylabel('Count')

# Bar chart for Salary
plt.subplot(1, 2, 2)
plt.bar(salary_counts.index, salary_counts.values, color='lightgreen')
plt.title('Distribution of Salary Levels')
plt.ylabel('Count')

plt.tight_layout()
plt.show()
# Out:
# StatementMeta(, bd6d472a-f6e9-4af4-9693-f3cde01de851, 38, Finished, Available)

# %%
plt.figure(figsize=(10, 6))
df[['Satisfaction Level', 'Last Evaluation', 'Time Spend Company']].boxplot()
plt.title('Box and Whisker Plots for Numeric Columns')
plt.ylabel('Values')
plt.tight_layout()
plt.show()
# Out:
# StatementMeta(, bd6d472a-f6e9-4af4-9693-f3cde01de851, 39, Finished, Available)

# %%
# Create a figure and an array of subplots with 1 row and 3 columns
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(10, 6))

# List of columns to plot
columns = ['Satisfaction Level', 'Last Evaluation', 'Time Spend Company']

# Colors for the boxes
colors = ['#ff9999', '#66b3ff', '#99ff99']

# Iterate over the columns, creating a box plot for each one
for ax, column, color in zip(axes, columns, colors):
    # Generate the boxplot with specified color
    bp = ax.boxplot(df[column].dropna(), patch_artist=True, medianprops=dict(color="yellow", linewidth=2))
    
    # Color the boxes
    for patch in bp['boxes']:
        patch.set_facecolor(color)
    
    # Remove grid lines
    ax.grid(False)
    
    # Set title with no spaces and proper case, replace underscores with spaces and capitalize
    formatted_title = column.replace('_', ' ').title()
    ax.set_title(formatted_title)
    
    # Set ylabel
    ax.set_ylabel('Values')

plt.tight_layout()  # Adjust subplots to fit into the figure area.
plt.show()
# Out:
# StatementMeta(, bd6d472a-f6e9-4af4-9693-f3cde01de851, 40, Finished, Available)

# %%
import seaborn as sns


# Setting the aesthetic style of the plots
sns.set(style="whitegrid")

# Creating a box plot to compare satisfaction levels across departments
plt.figure(figsize=(12, 6))
sns.boxplot(x='Departments', y='Satisfaction Level', data=df)
plt.title('Comparison of Employee Satisfaction Levels by Department')
plt.xticks(rotation=45)
plt.ylabel('Satisfaction Level')
plt.xlabel('Department')

# Show plot
plt.tight_layout()
plt.show()
# Out:
# StatementMeta(, bd6d472a-f6e9-4af4-9693-f3cde01de851, 41, Finished, Available)

# %%
# Calculate the average satisfaction level by length of service for the sales department and overall
avg_satisfaction_by_service_sales = df[df['Departments'] == 'sales'].groupby('Time Spend Company')['Satisfaction Level'].mean().reset_index()
avg_satisfaction_by_service_overall = df.groupby('Time Spend Company')['Satisfaction Level'].mean().reset_index()

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(avg_satisfaction_by_service_sales['Time Spend Company'], avg_satisfaction_by_service_sales['Satisfaction Level'], label='Sales')
plt.plot(avg_satisfaction_by_service_overall['Time Spend Company'], avg_satisfaction_by_service_overall['Satisfaction Level'], label='Overall', linestyle='--')
plt.title('Average Satisfaction Level by Length of Service')
plt.xlabel('Length of Service (Years)')
plt.ylabel('Average Satisfaction Level')
plt.legend()
plt.show()
# Out:
# StatementMeta(, bd6d472a-f6e9-4af4-9693-f3cde01de851, 42, Finished, Available)

# %%
sales_salary_satisfaction = df[df['Departments'] == 'sales'].groupby('Salary')['Satisfaction Level'].mean().sort_values().reset_index()
overall_salary_satisfaction = df.groupby('Salary')['Satisfaction Level'].mean().sort_values().reset_index()

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(sales_salary_satisfaction['Salary'], sales_salary_satisfaction['Satisfaction Level'], label='Sales', marker='o')
plt.plot(overall_salary_satisfaction['Salary'], overall_salary_satisfaction['Satisfaction Level'], label='Overall', marker='o', linestyle='--')
plt.title('Average Satisfaction Level by Salary Level')
plt.xlabel('Salary Level')
plt.ylabel('Average Satisfaction Level')
plt.legend()
plt.show()
# Out:
# StatementMeta(, bd6d472a-f6e9-4af4-9693-f3cde01de851, 43, Finished, Available)
